# %%
import sys
sys.path.insert(0, '..')

# %%
from spinesUtils import *

# %%
import pandas as pd

# %%
# %timeit df = read_csv('dataset.csv', transform2low_mem=False, turbo_method='polars')
# %timeit df = pd.read_csv('dataset.csv', engine='pyarrow')
# Out:
# 1.08 s ± 129 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.19 s ± 63.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
df
# Out:
#                 dt                            userid  \
# 0       2023-03-28  000036069ce54c9d8e02af8ad9e5e663
# 1       2023-06-28  000036069ce54c9d8e02af8ad9e5e663
# 2       2023-05-18  00005b86c78e4621bee189a8c68d43ef
# 3       2023-05-19  00009cac33c24d06b1aade55893b74ef
# 4       2023-06-10  00009cac33c24d06b1aade55893b74ef
# ...            ...                               ...
# 999995  2023-03-25  c0da9dedee804f8abb965d2d1d51a3a0
# 999996  2023-04-15  c0da9dedee804f8abb965d2d1d51a3a0
# 999997  2023-05-05  c0da9dedee804f8abb965d2d1d51a3a0
# 999998  2023-07-15  c0da9dedee804f8abb965d2d1d51a3a0
# 999999  2023-08-05  c0da9dedee804f8abb965d2d1d51a3a0
#
#                          last_category  vip_end_days vip_effective_type  \
# 0                    drama_detail_page           0.0                 其他
# 1                    drama_detail_page           4.0             连续付费月卡
# 2                    drama_detail_page          36.0               付费季卡
# ...
